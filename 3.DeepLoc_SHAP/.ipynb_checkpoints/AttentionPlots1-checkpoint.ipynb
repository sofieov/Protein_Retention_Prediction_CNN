# %%
import numpy as np
import scipy.stats
from pathlib import Path
import os
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
directory = ('Pos')

def normalize(directory):
    pos_att_matrix = np.array([])
    for file in os.listdir(directory):
        if file.endswith(".txt"): 
            file = os.path.join(directory, file)
            f = open(file)        
            att_vec = []
            for line in f:
                if not line.startswith('#'):
                    line = line.strip().split()
                    att_vec.append(float(line[2]))
            # The attention values are normalized   
            mean_att = np.mean(att_vec)
            std_att = np.std(att_vec) 
            norm = [(float(i)-mean_att)/std_att for i in att_vec]
            # The last 100 aa are extracted
            norm_100 = norm[-100:]
            norm_100 = np.asarray(norm_100)
            if pos_att_matrix.size == 0:
                pos_att_matrix = np.hstack((pos_att_matrix, norm_100))                    
            else: 
                pos_att_matrix = np.vstack((pos_att_matrix, norm_100))
        else:
            continue   
    return pos_att_matrix

# %%
def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

# %%
norm_att = np.zeros(pos_att_matrix.shape)
for prot_i in range(len(pos_att_matrix)):
    mean_att = np.mean(pos_att_matrix[prot_i])
    std = np.std(pos_att_matrix[prot_i])
    normalize = (pos_att_matrix[prot_i] - mean_att)/std
    norm_att[prot_i] = normalize

# %%
np.std(pos_att_matrix[0])
# Out:
# 0.3643910078530213

# %%
plt.boxplot([pos_att_matrix[0], norm_att[0]])
plt.show();

# %%
np.std(norm_att[0])
# Out:
# 0.9999999999999998

# %%
estimate_matrix = np.zeros((100,3))
for pos in range(100):
    mean_att, int_1, int_2 = mean_confidence_interval(pos_att_matrix[:,pos])
    estimate_matrix[pos,0] = mean_att
    estimate_matrix[pos,1] = int_1
    estimate_matrix[pos,2] = int_2

# %%
estimate_matrix_raw = np.zeros((100,3))
for pos in range(100):
    mean_att, int_1, int_2 = mean_confidence_interval(pos_att_matrix_raw[:,pos])
    estimate_matrix_raw[pos,0] = mean_att
    estimate_matrix_raw[pos,1] = int_1
    estimate_matrix_raw[pos,2] = int_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-51e43b13ceeb> in <module>()
#       1 estimate_matrix_raw = np.zeros((100,3))
#       2 for pos in range(100):
# ----> 3     mean_att, int_1, int_2 = mean_confidence_interval(pos_att_matrix_raw[:,pos])
#       4     estimate_matrix_raw[pos,0] = mean_att
#       5     estimate_matrix_raw[pos,1] = int_1
#
# NameError: name 'pos_att_matrix_raw' is not defined

# %%
plt.figure(figsize=(20,10))
plt.plot(estimate_matrix_raw)
plt.show();

# %%
plt.figure(figsize=(20,10))
plt.plot(estimate_matrix)
plt.show();

# %%
plt.figure(figsize=(20,10))
plt.violinplot(pos_att_matrix)
plt.show();

# %%
plt.figure(figsize=(20,10))
plt.boxplot(pos_att_matrix[:,80:])
plt.show();

# %%
plt.figure(figsize=(20,10))
plt.boxplot(pos_att_matrix[:,80:])
plt.show();

# %% [markdown]
# # Main

# %%
pos_att_matrix = normalize(directory)
