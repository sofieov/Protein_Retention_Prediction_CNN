# %% [markdown]
# # =================== Import ===================

# %%
import numpy as np
import scipy.stats
from pathlib import Path
import os
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # =================== Variables ===================

# %%
data = np.load('5.ER_dataset.npz')

# %% [markdown]
# # =================== Functions ===================

# %%
def normalizing():
    '''Function to normalize the attention values of the proteins, before only using the last 100aa in the sequence'''
    directory = ('Pos_Output_Attention')
    pos_att_matrix = np.array([])
    for file in os.listdir(directory):
        if file.endswith(".txt"): 
            file = os.path.join(directory, file)
            f = open(file)        
            att_vec = []
            for line in f:
                if not line.startswith('#'):
                    line = line.strip().split()
                    att_vec.append(float(line[2]))
            # The attention values are normalized   
            mean_att = np.mean(att_vec)
            std_att = np.std(att_vec) 
            norm = [(float(i)-mean_att)/std_att for i in att_vec]
            # The last 100 aa are extracted
            norm_100 = norm[-100:]
            norm_100 = np.asarray(norm_100)
            if pos_att_matrix.size == 0:
                pos_att_matrix = np.hstack((pos_att_matrix, norm_100))                    
            else: 
                pos_att_matrix = np.vstack((pos_att_matrix, norm_100))
        else:
            continue 
    return pos_att_matrix


def mean_confidence_interval(data, confidence=0.95):
    '''Function to find the confidence interval'''
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h





norm_att = np.zeros(pos_att_matrix.shape)
for prot_i in range(len(pos_att_matrix)):
    mean_att = np.mean(pos_att_matrix[prot_i])
    std = np.std(pos_att_matrix[prot_i])
    normalize = (pos_att_matrix[prot_i] - mean_att)/std
    norm_att[prot_i] = normalize

# %%
plt.figure(figsize=(20,10))
plt.boxplot(pos_att_matrix[:,80:])
plt.show();

# %% [markdown]
# # =================== Main ===================

# %%
pos_att_matrix = normaliz()
#m, m-h, m+h = mean_confidence_interval(data, confidence=0.95)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-e0c77aa0ebd1> in <module>()
#       1 pos_att_matrix = normalizing()
# ----> 2 m, m, m = mean_confidence_interval(data)
#
# <ipython-input-73-69475e82bf2d> in mean_confidence_interval(data)
#      31     '''Function to find the confidence interval'''
#      32     confidence=0.95
# ---> 33     a = 1.0 * np.array(data)
#      34     n = len(a)
#      35     m, se = np.mean(a), scipy.stats.sem(a)
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NpzFile'

# %%
plt.figure(figsize=(20,10))
plt.boxplot(pos_att_matrix[:,80:])
plt.show();
