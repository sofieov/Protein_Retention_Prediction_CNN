# %%
import numpy as np
import matplotlib.pyplot as plt
import os.path

# %%
output_attention = os.path.abspath('Pos_Output_Atttention/output_attention_100.txt') 
#os.path.abspath

file = open(output_attention)
att_vec = []
for line in file:
    if not line.startswith("#"):
        line = line.strip().split()
        att_vec.append(float(line[2]))

# %%
for i
# Out:
#   File "<ipython-input-14-5c31f1150e0e>", line 1
#     for i
#           ^
# SyntaxError: invalid syntax

# %%
#plt.boxplot(att_vec)
#plt.show()

# %%
#plt.boxplot(att_vec2)
#plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(np.arange(len(att_vec)), att_vec)
#plt.plot(np.arange(len(att_vec2)), att_vec2)
plt.show()
